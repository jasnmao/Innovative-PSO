# %%
import numpy as np

class Particle:
    def __init__(self, dim, minx, maxx):
        self.position = np.random.uniform(minx, maxx, dim)
        self.velocity = np.random.uniform(-1, 1, size=dim)
        self.pbest_position = self.position.copy()
        self.pbest_score = np.inf
        self.score = np.inf
        self.dim=dim
        
    def update_velocity(self, inertia, c1, c2, gbest_position,repulsive_sources, 
                        repulsion_strength=1.0,attraction_scale=1.0, epilson=1e-6):

        r1 = np.random.rand(self.dim)
        r2 = np.random.rand(self.dim)
        r3 = np.random.rand(self.dim)

        dp = self.pbest_position - self.position
        distance_p = np.linalg.norm(dp)
        # 高斯衰减系数
        cognitive_weight = c1 * np.exp(-distance_p** 2 / (2 * attraction_scale**2))
        cognitive = cognitive_weight * r1* dp 

        dg = gbest_position - self.position
        distance_g = np.linalg.norm(dg)
        social_weight = c2 * np.exp(-distance_g**2/ (2 * attraction_scale**2))
        social = social_weight * r2* dg 
        
        repulsion = np.zeros_like(self.velocity)
        for source in repulsive_sources:
            vec = self.position - source
            distance_v = np.linalg.norm(vec)
            if distance_v < epilson:
                continue
            repulsion_strength_scaled =  np.exp(-distance_v** 2 / (2 * attraction_scale**2))
            repulsion += (repulsion_strength_scaled) * r3* (vec)
            
        self.velocity = inertia * self.velocity + cognitive + social + repulsion_strength*repulsion

    def update_position(self, minx, maxx):
        self.position += self.velocity
        self.position = np.clip(self.position, minx, maxx)

    def mutation(self,pm):
        if np.random.rand()<pm:
            theta=1.0/(1.0+np.exp(-self.score))
            self.position+=np.random.normal(0,theta,size=self.position.shape)
    
def hybridize(parent1, parent2, dim, minx, maxx,pm=0.1):
    alpha = np.random.rand()
    child_pos = alpha * parent1.position + (1-alpha) * parent2.position
    child_vel = alpha * parent1.velocity + (1-alpha) * parent2.velocity
    if np.random.rand() < pm:
        child_pos+=np.random.normal(0,0.5,size=child_pos.shape)
    child = Particle(dim, minx, maxx)

    child.position = child_pos
    child.velocity = child_vel
    return child

def select_parents(remaining,k=2,replace=False):
    scores=np.array([p.score for p in remaining])
    fitness=1.0/(scores+1e-6)
    total_fitness=np.sum(fitness)
    probs=fitness/total_fitness
    parents_indices=np.random.choice(len(remaining),k,replace=replace,p=probs)
    return [remaining[i] for i in parents_indices]



def modified_pso(objective_func, dim, minx, maxx,
                 n_particles=50, n_iterations=200, inertia=0.8,pm=0.1, 
                 c1=1.5, c2=1.5, k_eliminate=2, attraction_scale=1.0):
    particles = [Particle(dim, minx, maxx) for _ in range(n_particles)]
    gbest_position = np.zeros(dim)
    gbest_score = np.inf

    for iteration in range(n_iterations):
        current_inertia = inertia - (inertia - 0.4) * (iteration / n_iterations)
        for p in particles:
            p.score = objective_func(p.position)
            if p.score < p.pbest_score:
                p.pbest_score = p.score
                p.pbest_position = p.position.copy()
            if p.score < gbest_score:
                gbest_score = p.score
                gbest_position = p.position.copy()
            
        particles.sort(key=lambda x: x.score, reverse=True)
        eliminated = particles[:k_eliminate]
        remaining = particles[k_eliminate:]

        new_particles = []
        for _ in range(k_eliminate):
            parents = select_parents(remaining, 2, replace=False)
            child = hybridize(parents[0], parents[1], dim, minx, maxx)
            new_particles.append(child)
        
        repulsive_sources = [e.position.copy() for e in eliminated]

        particles = remaining + new_particles
        for p in particles:
            p.update_velocity(current_inertia, c1, c2, gbest_position,
                            repulsive_sources,attraction_scale)
            p.update_position(minx, maxx)
            p.mutation(pm)


        print(f"Iteration {iteration}, Best Score: {gbest_score:.4f}")

    return gbest_position, gbest_score

def rastrigin(x):
    return 10*len(x) + np.sum(x**2 - 10*np.cos(2*np.pi*x))

if __name__ == "__main__":

    dim = 10
    n_particles = 80
    n_iterations = 200
    minx = -5.12
    maxx = 5.12
    inertia=0.8
    c1=c2=1.2
    k_eliminate=3
    pm=0.08

    best_position, best_score = modified_pso(
        rastrigin, dim, minx, maxx, n_particles, n_iterations,
        inertia,pm,c1,c2,k_eliminate,attraction_scale=2.0  # 可以调整这个参数来控制信息素衰减速度
    )
    print("Optimized Position:", best_position)
    print("Optimized Score:", best_score)
# Out:
# Iteration 0, Best Score: 106.1596
# Iteration 1, Best Score: 106.1596
# Iteration 2, Best Score: 95.1822
# Iteration 3, Best Score: 95.1822
# Iteration 4, Best Score: 90.4843
# Iteration 5, Best Score: 90.4843
# Iteration 6, Best Score: 90.4843
# Iteration 7, Best Score: 90.4843
# Iteration 8, Best Score: 90.4843
# Iteration 9, Best Score: 90.4843
# Iteration 10, Best Score: 90.4843
# Iteration 11, Best Score: 90.3519
# Iteration 12, Best Score: 85.3865
# Iteration 13, Best Score: 83.6537
# Iteration 14, Best Score: 83.5914
# Iteration 15, Best Score: 83.5914
# Iteration 16, Best Score: 83.0527
# Iteration 17, Best Score: 82.4456
# Iteration 18, Best Score: 82.1736
# Iteration 19, Best Score: 82.0826
# Iteration 20, Best Score: 82.0824
# Iteration 21, Best Score: 82.0824
# Iteration 22, Best Score: 82.0824
# Iteration 23, Best Score: 82.0824
# Iteration 24, Best Score: 73.3954
# Iteration 25, Best Score: 73.3954
# Iteration 26, Best Score: 73.0632
# Iteration 27, Best Score: 73.0632
# Iteration 28, Best Score: 73.0632
# Iteration 29, Best Score: 73.0632
# Iteration 30, Best Score: 70.2310
# Iteration 31, Best Score: 69.9954
# Iteration 32, Best Score: 69.9954
# Iteration 33, Best Score: 69.1043
# Iteration 34, Best Score: 67.1127
# Iteration 35, Best Score: 67.1127
# Iteration 36, Best Score: 67.1127
# Iteration 37, Best Score: 61.0114
# Iteration 38, Best Score: 59.8187
# Iteration 39, Best Score: 59.0421
# Iteration 40, Best Score: 58.5364
# Iteration 41, Best Score: 58.2043
# Iteration 42, Best Score: 57.9836
# Iteration 43, Best Score: 57.8351
# Iteration 44, Best Score: 57.7342
# Iteration 45, Best Score: 57.6649
# Iteration 46, Best Score: 57.6170
# Iteration 47, Best Score: 57.5838
# Iteration 48, Best Score: 57.5607
# Iteration 49, Best Score: 57.5446
# Iteration 50, Best Score: 54.7614
# Iteration 51, Best Score: 53.4166
# Iteration 52, Best Score: 52.7747
# Iteration 53, Best Score: 52.4707
# Iteration 54, Best Score: 52.3273
# Iteration 55, Best Score: 52.2603
# Iteration 56, Best Score: 52.2292
# Iteration 57, Best Score: 52.2149
# Iteration 58, Best Score: 52.2084
# Iteration 59, Best Score: 52.2056
# Iteration 60, Best Score: 52.2044
# Iteration 61, Best Score: 52.2039
# Iteration 62, Best Score: 52.2038
# Iteration 63, Best Score: 52.2038
# Iteration 64, Best Score: 52.2038
# Iteration 65, Best Score: 52.2038
# Iteration 66, Best Score: 52.2038
# Iteration 67, Best Score: 52.2038
# Iteration 68, Best Score: 52.2038
# Iteration 69, Best Score: 52.2038
# Iteration 70, Best Score: 52.2038
# Iteration 71, Best Score: 48.4254
# Iteration 72, Best Score: 45.6582
# Iteration 73, Best Score: 45.6582
# Iteration 74, Best Score: 45.6582
# Iteration 75, Best Score: 45.6582
# Iteration 76, Best Score: 45.6582
# Iteration 77, Best Score: 45.6582
# Iteration 78, Best Score: 45.6582
# Iteration 79, Best Score: 45.6582
# Iteration 80, Best Score: 45.6582
# Iteration 81, Best Score: 45.4884
# Iteration 82, Best Score: 45.4884
# Iteration 83, Best Score: 45.1243
# Iteration 84, Best Score: 44.5969
# Iteration 85, Best Score: 44.4431
# Iteration 86, Best Score: 44.4431
# Iteration 87, Best Score: 44.1181
# Iteration 88, Best Score: 43.8863
# Iteration 89, Best Score: 42.0938
# Iteration 90, Best Score: 41.2075
# Iteration 91, Best Score: 41.2075
# Iteration 92, Best Score: 41.2075
# Iteration 93, Best Score: 41.2075
# Iteration 94, Best Score: 41.2075
# Iteration 95, Best Score: 41.2075
# Iteration 96, Best Score: 41.2075
# Iteration 97, Best Score: 38.9261
# Iteration 98, Best Score: 38.9261
# Iteration 99, Best Score: 38.9261
# Iteration 100, Best Score: 38.9261
# Iteration 101, Best Score: 38.9261
# Iteration 102, Best Score: 38.9261
# Iteration 103, Best Score: 38.9261
# Iteration 104, Best Score: 38.9261
# Iteration 105, Best Score: 36.9525
# Iteration 106, Best Score: 36.9525
# Iteration 107, Best Score: 36.9525
# Iteration 108, Best Score: 36.9016
# Iteration 109, Best Score: 36.9016
# Iteration 110, Best Score: 36.9016
# Iteration 111, Best Score: 36.9016
# Iteration 112, Best Score: 35.5238
# Iteration 113, Best Score: 35.5238
# Iteration 114, Best Score: 35.5238
# Iteration 115, Best Score: 35.4115
# Iteration 116, Best Score: 35.4115
# Iteration 117, Best Score: 35.4115
# Iteration 118, Best Score: 35.4115
# Iteration 119, Best Score: 35.4115
# Iteration 120, Best Score: 35.4115
# Iteration 121, Best Score: 34.5113
# Iteration 122, Best Score: 34.5113
# Iteration 123, Best Score: 34.5113
# Iteration 124, Best Score: 34.5113
# Iteration 125, Best Score: 34.5113
# Iteration 126, Best Score: 34.5113
# Iteration 127, Best Score: 34.5113
# Iteration 128, Best Score: 34.5113
# Iteration 129, Best Score: 34.5113
# Iteration 130, Best Score: 34.5113
# Iteration 131, Best Score: 34.5113
# Iteration 132, Best Score: 34.5113
# Iteration 133, Best Score: 33.2113
# Iteration 134, Best Score: 33.1928
# Iteration 135, Best Score: 28.9248
# Iteration 136, Best Score: 28.9248
# Iteration 137, Best Score: 28.9248
# Iteration 138, Best Score: 28.9248
# Iteration 139, Best Score: 28.9248
# Iteration 140, Best Score: 28.9248
# Iteration 141, Best Score: 28.9248
# Iteration 142, Best Score: 28.9248
# Iteration 143, Best Score: 28.9248
# Iteration 144, Best Score: 28.9248
# Iteration 145, Best Score: 28.9248
# Iteration 146, Best Score: 28.9248
# Iteration 147, Best Score: 28.9248
# Iteration 148, Best Score: 28.9248
# Iteration 149, Best Score: 28.9248
# Iteration 150, Best Score: 28.3732
# Iteration 151, Best Score: 27.5571
# Iteration 152, Best Score: 27.2178
# Iteration 153, Best Score: 27.0666
# Iteration 154, Best Score: 25.4903
# Iteration 155, Best Score: 25.4903
# Iteration 156, Best Score: 25.4903
# Iteration 157, Best Score: 18.2261
# Iteration 158, Best Score: 17.6321
# Iteration 159, Best Score: 17.3303
# Iteration 160, Best Score: 17.3303
# Iteration 161, Best Score: 17.3303
# Iteration 162, Best Score: 17.3303
# Iteration 163, Best Score: 17.3303
# Iteration 164, Best Score: 17.3303
# Iteration 165, Best Score: 17.3303
# Iteration 166, Best Score: 17.3303
# Iteration 167, Best Score: 16.1899
# Iteration 168, Best Score: 16.1019
# Iteration 169, Best Score: 15.7366
# Iteration 170, Best Score: 14.7495
# Iteration 171, Best Score: 14.7495
# Iteration 172, Best Score: 14.2478
# Iteration 173, Best Score: 14.2478
# Iteration 174, Best Score: 14.2478
# Iteration 175, Best Score: 13.6662
# Iteration 176, Best Score: 13.6662
# Iteration 177, Best Score: 13.5758
# Iteration 178, Best Score: 13.5020
# Iteration 179, Best Score: 13.5008
# Iteration 180, Best Score: 13.5008
# Iteration 181, Best Score: 13.5008
# Iteration 182, Best Score: 13.5008
# Iteration 183, Best Score: 13.5008
# Iteration 184, Best Score: 13.5008
# Iteration 185, Best Score: 13.5008
# Iteration 186, Best Score: 13.5008
# Iteration 187, Best Score: 13.5008
# Iteration 188, Best Score: 13.5008
# Iteration 189, Best Score: 13.5008
# Iteration 190, Best Score: 13.5008
# Iteration 191, Best Score: 13.4345
# Iteration 192, Best Score: 13.3540
# Iteration 193, Best Score: 13.3540
# Iteration 194, Best Score: 13.3540
# Iteration 195, Best Score: 13.3540
# Iteration 196, Best Score: 13.3540
# Iteration 197, Best Score: 13.3540
# Iteration 198, Best Score: 13.3540
# Iteration 199, Best Score: 13.3540
# Optimized Position: [-1.00384579  1.98354739 -0.98402756  0.02207353 -1.02888791 -0.98830119
#  -1.00334001 -1.9990409  -0.00612048  0.00230843]
# Optimized Score: 13.353961600998574
